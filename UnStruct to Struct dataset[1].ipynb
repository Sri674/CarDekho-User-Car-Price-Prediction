# %%
import pandas as pd
Chennai_cars= pd.read_csv("G:/chennai_cars - chennai_cars.csv.csv")

# %%
Chennai_cars
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...                                                 ...
# 1414  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1415  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1416  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1417  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1418  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
Chennai_cars["new_car_detail"]
# Out:
# 0       {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1       {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2       {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3       {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4       {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#                               ...
# 1414    {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1415    {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1416    {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1417    {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1418    {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
# Name: new_car_detail, Length: 1419, dtype: object

# %%
                                  #CHENNAI CAR DETAILS

import pandas as pd

data=[Chennai_cars["new_car_detail"]]
data
# Out:
# [0       {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
#  1       {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
#  2       {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
#  3       {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#  4       {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#                                ...
#  1414    {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#  1415    {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#  1416    {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
#  1417    {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#  1418    {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
#  Name: new_car_detail, Length: 1419, dtype: object]

# %%
list_of_dicts = Chennai_cars["new_car_detail"].tolist()

# %%
       pd.DataFrame will not flatterened nested dictionary, so we used pd.json_normalize(data_dict)

# %%
import pandas as pd
import ast

data= list_of_dicts

data_dict = [ast.literal_eval(item) for item in data]

df_1=pd.json_normalize(data_dict)

df_1
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  centralVariantId  \
# 0            Kia          Kia Sonet       2022              8654
# ...

# %%
Chennai_cars["new_car_overview"]
# Out:
# 0       {'heading': 'Car overview', 'top': [{'key': 'R...
# 1       {'heading': 'Car overview', 'top': [{'key': 'R...
# 2       {'heading': 'Car overview', 'top': [{'key': 'R...
# 3       {'heading': 'Car overview', 'top': [{'key': 'R...
# 4       {'heading': 'Car overview', 'top': [{'key': 'R...
#                               ...
# 1414    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1415    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1416    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1417    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1418    {'heading': 'Car overview', 'top': [{'key': 'R...
# Name: new_car_overview, Length: 1419, dtype: object

# %%
list_of_dicts2=Chennai_cars["new_car_overview"].tolist()

# %%
import pandas as pd
import ast 


data_dict2 = [ast.literal_eval(item) if isinstance(item, str) else item for item in list_of_dicts2]

flattened_data_list = []

for data_item in data_dict2:
    
    heading = data_item.get('heading', '')

   
    flattened_data = {'Heading': heading}

   if 'top' in data_item and isinstance(data_item['top'], list):
        
        for item in data_item['top']:
            
            key = item.get('key', '')
            value = item.get('value', '')
           
            if key and value:
                flattened_data[key] = value

   
    flattened_data_list.append(flattened_data)


df_2 = pd.DataFrame(flattened_data_list)


df_2
# Out:
#            Heading Registration Year     Insurance Validity Fuel Type  \
# 0     Car overview              2022  Third Party insurance    Petrol
# 1     Car overview          Feb 2015          Comprehensive    Petrol
# 2     Car overview              2021  Third Party insurance    Petrol
# 3     Car overview          May 2015          Comprehensive    Petrol
# 4     Car overview              2015  Third Party insurance    Petrol
# ...            ...               ...                    ...       ...
# 1414  Car overview          Jun 2018  Third Party insurance    Petrol
# 1415  Car overview          Feb 2019  Third Party insurance    Diesel
# 1416  Car overview          Aug 2018          Not Available    Petrol
# 1417  Car overview          Aug 2017          Comprehensive    Diesel
# 1418  Car overview          Oct 2019          Comprehensive    Diesel
#
#         Seats  Kms Driven   RTO    Ownership Engine Displacement Transmission  \
# ...

# %%
Chennai_cars["new_car_feature"]
# Out:
# 0       {'heading': 'Features', 'top': [{'value': 'Pow...
# 1       {'heading': 'Features', 'top': [{'value': 'Low...
# 2       {'heading': 'Features', 'top': [{'value': 'Pow...
# 3       {'heading': 'Features', 'top': [{'value': 'Pow...
# 4       {'heading': 'Features', 'top': [{'value': 'Pow...
#                               ...
# 1414    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1415    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1416    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1417    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1418    {'heading': 'Features', 'top': [{'value': 'Pow...
# Name: new_car_feature, Length: 1419, dtype: object

# %%
list_of_dicts3=Chennai_cars["new_car_feature"].tolist()

# %%
import pandas as pd
import ast

data = [ast.literal_eval(item) for item in list_of_dicts3]

top_features = []
category_features = {
    'Comfort & Convenience': [],
    'Interior': [],
    'Exterior': [],
    'Safety': [],
    'Entertainment & Communication': []
}

for entry in data:
    top_features += [item['value'] for item in entry['top']]

    for section in entry['data']:
        category_name = section['heading']
        if category_name in category_features: 
            for item in section['list']:
                category_features[category_name].append(item['value'])

# Find the maximum length of the lists so that we can align the data
max_len = max(len(top_features), *[len(category_features[cat]) for cat in category_features])

# Padding shorter lists with empty strings to align the columns
top_features += [''] * (max_len - len(top_features))
for cat in category_features:
    category_features[cat] += [''] * (max_len - len(category_features[cat]))

final_data = {
    'Top Features': top_features,
    'Comfort & Convenience': category_features['Comfort & Convenience'],
    'Interior': category_features['Interior'],
    'Exterior': category_features['Exterior'],
    'Safety': category_features['Safety'],
    'Entertainment & Communication': category_features['Entertainment & Communication']
}

df_3 = pd.DataFrame(final_data)

df_3
# Out:
#                  Top Features   Comfort & Convenience  \
# 0              Power Steering          Power Steering
# 1         Power Windows Front     Power Windows Front
# 2             Air Conditioner      Power Windows Rear
# 3                      Heater  Low Fuel Warning Light
# 4      Adjustable Head Lights  Accessory Power Outlet
# ...                       ...                     ...
# 33210
# 33211
# 33212
# 33213
# 33214
#
#                          Interior                                    Exterior  \
# 0                 Air Conditioner                      Adjustable Head Lights
# 1                          Heater                            Fog Lights Front
# 2             Adjustable Steering  Power Adjustable Exterior Rear View Mirror
# 3                Digital Odometer           Electric Folding Rear View Mirror
# 4      Electronic Multi Tripmeter                        Rear Window Defogger
# ...                           ...                                         ...
# ...

# %%
Chennai_cars["new_car_specs"]
# Out:
# 0       {'heading': 'Specifications', 'top': [{'key': ...
# 1       {'heading': 'Specifications', 'top': [{'key': ...
# 2       {'heading': 'Specifications', 'top': [{'key': ...
# 3       {'heading': 'Specifications', 'top': [{'key': ...
# 4       {'heading': 'Specifications', 'top': [{'key': ...
#                               ...
# 1414    {'heading': 'Specifications', 'top': [{'key': ...
# 1415    {'heading': 'Specifications', 'top': [{'key': ...
# 1416    {'heading': 'Specifications', 'top': [{'key': ...
# 1417    {'heading': 'Specifications', 'top': [{'key': ...
# 1418    {'heading': 'Specifications', 'top': [{'key': ...
# Name: new_car_specs, Length: 1419, dtype: object

# %%
list_of_dicts4=Chennai_cars["new_car_specs"].tolist()

# %%
import pandas as pd
import ast 

data_dict4 = [ast.literal_eval(item) if isinstance(item, str) else item for item in list_of_dicts4]

flattened_data_list = []

for data_item in data_dict4:
    heading = data_item.get('heading', '')

    flattened_data = {'Heading': heading}

    if 'top' in data_item and isinstance(data_item['top'], list):
        for item in data_item['top']:
            key = item.get('key', '')
            value = item.get('value', '')
           
            if key and value:
                flattened_data[key] = value

 
    flattened_data_list.append(flattened_data)


df_4 = pd.DataFrame(flattened_data_list)

df_4
# Out:
#              Heading   Engine  Max Power   Torque Wheel Size Seats     Mileage
# 0     Specifications   998 CC  118.36bhp    172nm         16     5         NaN
# 1     Specifications  1196 CC      73bhp    101Nm        NaN     7  15.37 kmpl
# 2     Specifications   999 CC   98.63bhp    160Nm         16     5     20 kmpl
# 3     Specifications  1086 CC   68.05bhp  99.04Nm        NaN     5  19.81 kmpl
# 4     Specifications  1199 CC    88.7bhp    110Nm         15     5   18.7 kmpl
# ...              ...      ...        ...      ...        ...   ...         ...
# 1414  Specifications  1197 CC   81.80bhp    113Nm        NaN     5     22 kmpl
# 1415  Specifications  1461 CC    83.8bhp    200Nm         16     5  19.87 kmpl
# 1416  Specifications  1198 CC   108.5bhp    170Nm         16     5     17 kmpl
# 1417  Specifications  1968 CC     141bhp    340Nm         18     5  16.65 kmpl
# 1418  Specifications  1995 CC     188bhp    400Nm         18     5  21.76 kmpl
#
# [1419 rows x 7 columns]

# %%
Chennai_cars["car_links"]
# Out:
# 0       https://www.cardekho.com/used-car-details/used...
# 1       https://www.cardekho.com/buy-used-car-details/...
# 2       https://www.cardekho.com/used-car-details/used...
# 3       https://www.cardekho.com/buy-used-car-details/...
# 4       https://www.cardekho.com/used-car-details/used...
#                               ...
# 1414    https://www.cardekho.com/used-car-details/used...
# 1415    https://www.cardekho.com/used-car-details/used...
# 1416    https://www.cardekho.com/used-car-details/used...
# 1417    https://www.cardekho.com/used-car-details/used...
# 1418    https://www.cardekho.com/used-car-details/used...
# Name: car_links, Length: 1419, dtype: object

# %%
import pandas as pd

df_5=pd.DataFrame(Chennai_cars["car_links"])

df_5
# Out:
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1414  https://www.cardekho.com/used-car-details/used...
# 1415  https://www.cardekho.com/used-car-details/used...
# 1416  https://www.cardekho.com/used-car-details/used...
# 1417  https://www.cardekho.com/used-car-details/used...
# 1418  https://www.cardekho.com/used-car-details/used...
#
# [1419 rows x 1 columns]

# %%
import pandas as pd

df_3_truncated = df_3.iloc[:1419]


overall_chennai_df = pd.concat([df_1,df_2,df_3_truncated,df_4,df_5], axis=1)

overall_chennai_df
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  ...  \
# 0            Kia          Kia Sonet       2022  ...
# ...

# %%
overall_chennai_df["City"]="Chennai"

# %%
overall_chennai_df
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  ...  \
# 0            Kia          Kia Sonet       2022  ...
# ...

# %%
overall_chennai_df.to_csv("overall_chennai_df.csv",index=False)

# %%
                               BANGALORE CAR DETAILS

import pandas as pd
Bangalore_cars= pd.read_csv("G:/bangalore_cars - bangalore_cars.csv.csv")

# %%
Bangalore_cars
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 4     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1476  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1477  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1478  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1479  {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1480  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
Bangalore_cars["new_car_detail"]
# Out:
# 0       {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1       {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2       {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3       {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 4       {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#                               ...
# 1476    {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1477    {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1478    {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1479    {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1480    {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# Name: new_car_detail, Length: 1481, dtype: object

# %%
list_of_dicts11 = Bangalore_cars["new_car_detail"].tolist()

# %%
import pandas as pd
import ast

data= list_of_dicts11

data_dict = [ast.literal_eval(item) for item in data]

df_11=pd.json_normalize(data_dict)

df_11
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1476   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 1477   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 1478   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 1479   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 1480   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem               model  modelYear  centralVariantId  \
# ...

# %%
Bangalore_cars["new_car_overview"]
# Out:
# 0       {'heading': 'Car overview', 'top': [{'key': 'R...
# 1       {'heading': 'Car overview', 'top': [{'key': 'R...
# 2       {'heading': 'Car overview', 'top': [{'key': 'R...
# 3       {'heading': 'Car overview', 'top': [{'key': 'R...
# 4       {'heading': 'Car overview', 'top': [{'key': 'R...
#                               ...
# 1476    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1477    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1478    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1479    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1480    {'heading': 'Car overview', 'top': [{'key': 'R...
# Name: new_car_overview, Length: 1481, dtype: object

# %%
list_of_dicts12=Bangalore_cars["new_car_overview"].tolist()

# %%
import pandas as pd
import ast 


data_dict2 = [ast.literal_eval(item) if isinstance(item, str) else item for item in list_of_dicts12]

flattened_data_list = []

for data_item in data_dict2:
   
    heading = data_item.get('heading', '')

 flattened_data = {'Heading': heading}

   
    if 'top' in data_item and isinstance(data_item['top'], list):
       
        for item in data_item['top']:
           
            key = item.get('key', '')
            value = item.get('value', '')
           
            if key and value:
                flattened_data[key] = value

    
    flattened_data_list.append(flattened_data)


df_12 = pd.DataFrame(flattened_data_list)

df_12
# Out:
#            Heading Registration Year     Insurance Validity Fuel Type  \
# 0     Car overview              2015  Third Party insurance    Petrol
# 1     Car overview          Feb 2018          Comprehensive    Petrol
# 2     Car overview         Sept 2018          Comprehensive    Petrol
# 3     Car overview          Dec 2014          Comprehensive    Petrol
# 4     Car overview              2015  Third Party insurance    Diesel
# ...            ...               ...                    ...       ...
# 1476  Car overview          May 2012          Comprehensive    Diesel
# 1477  Car overview          Jun 2008  Third Party insurance    Petrol
# 1478  Car overview         Sept 2014          Comprehensive    Petrol
# 1479  Car overview          Dec 2018          Comprehensive    Diesel
# 1480  Car overview          May 2017          Comprehensive    Petrol
#
#         Seats    Kms Driven   RTO     Ownership Engine Displacement  \
# ...

# %%
Bangalore_cars["new_car_feature"]
# Out:
# 0       {'heading': 'Features', 'top': [{'value': 'Pow...
# 1       {'heading': 'Features', 'top': [{'value': 'Pow...
# 2       {'heading': 'Features', 'top': [{'value': 'Pow...
# 3       {'heading': 'Features', 'top': [{'value': 'Pow...
# 4       {'heading': 'Features', 'top': [{'value': 'Pow...
#                               ...
# 1476    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1477    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1478    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1479    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1480    {'heading': 'Features', 'top': [{'value': 'Pow...
# Name: new_car_feature, Length: 1481, dtype: object

# %%
list_of_dicts13=Bangalore_cars["new_car_feature"].tolist()

# %%
import pandas as pd
import ast

data = [ast.literal_eval(item) for item in list_of_dicts13]

top_features = []
category_features = {
    'Comfort & Convenience': [],
    'Interior': [],
    'Exterior': [],
    'Safety': [],
    'Entertainment & Communication': []
}

for entry in data:
    top_features += [item['value'] for item in entry['top']]

    for section in entry['data']:
        category_name = section['heading']
        if category_name in category_features:  
            for item in section['list']:
                category_features[category_name].append(item['value'])

max_len = max(len(top_features), *[len(category_features[cat]) for cat in category_features])


top_features += [''] * (max_len - len(top_features))
for cat in category_features:
    category_features[cat] += [''] * (max_len - len(category_features[cat]))


final_data = {
    'Top Features': top_features,
    'Comfort & Convenience': category_features['Comfort & Convenience'],
    'Interior': category_features['Interior'],
    'Exterior': category_features['Exterior'],
    'Safety': category_features['Safety'],
    'Entertainment & Communication': category_features['Entertainment & Communication']
}


df_13 = pd.DataFrame(final_data)

df_13
# Out:
#                  Top Features   Comfort & Convenience  \
# 0              Power Steering          Power Steering
# 1         Power Windows Front     Power Windows Front
# 2             Air Conditioner      Power Windows Rear
# 3                      Heater     Remote Trunk Opener
# 4      Adjustable Head Lights  Remote Fuel Lid Opener
# ...                       ...                     ...
# 34221
# 34222
# 34223
# 34224
# 34225
#
#                          Interior  \
# 0                 Air Conditioner
# 1                          Heater
# 2                Digital Odometer
# 3      Electronic Multi Tripmeter
# 4               Fabric Upholstery
# ...                           ...
# 34221
# 34222
# 34223
# 34224
# 34225
#
#                                             Exterior  \
# 0                             Adjustable Head Lights
# 1      Manually Adjustable Exterior Rear View Mirror
# 2                                       Wheel Covers
# ...

# %%
Bangalore_cars["new_car_specs"]
# Out:
# 0       {'heading': 'Specifications', 'top': [{'key': ...
# 1       {'heading': 'Specifications', 'top': [{'key': ...
# 2       {'heading': 'Specifications', 'top': [{'key': ...
# 3       {'heading': 'Specifications', 'top': [{'key': ...
# 4       {'heading': 'Specifications', 'top': [{'key': ...
#                               ...
# 1476    {'heading': 'Specifications', 'top': [{'key': ...
# 1477    {'heading': 'Specifications', 'top': [{'key': ...
# 1478    {'heading': 'Specifications', 'top': [{'key': ...
# 1479    {'heading': 'Specifications', 'top': [{'key': ...
# 1480    {'heading': 'Specifications', 'top': [{'key': ...
# Name: new_car_specs, Length: 1481, dtype: object

# %%
list_of_dicts14=Bangalore_cars["new_car_specs"].tolist()

# %%
import pandas as pd
import ast 


data_dict4 = [ast.literal_eval(item) if isinstance(item, str) else item for item in list_of_dicts14]

flattened_data_list = []

for data_item in data_dict4:
    
    heading = data_item.get('heading', '')

   flattened_data = {'Heading': heading}

   
    if 'top' in data_item and isinstance(data_item['top'], list):
        
        for item in data_item['top']:
          
            key = item.get('key', '')
            value = item.get('value', '')
           
            if key and value:
                flattened_data[key] = value

    
    flattened_data_list.append(flattened_data)


df_14 = pd.DataFrame(flattened_data_list)

df_14
# Out:
#              Heading     Mileage   Engine  Max Power    Torque Seats  \
# 0     Specifications   23.1 kmpl   998 CC   67.04bhp      90Nm     5
# 1     Specifications     17 kmpl  1497 CC  121.31bhp     150Nm     5
# 2     Specifications  23.84 kmpl  1199 CC      84bhp     114Nm     5
# 3     Specifications   19.1 kmpl  1197 CC   81.86bhp  113.75Nm     5
# 4     Specifications  23.65 kmpl  1248 CC    88.5bhp     200Nm     5
# ...              ...         ...      ...        ...       ...   ...
# 1476  Specifications  12.55 kmpl  2982 CC   168.5bhp     343Nm     7
# 1477  Specifications     15 kmpl  1586 CC     104.68       145     5
# 1478  Specifications   19.4 kmpl  1198 CC    86.8bhp     109Nm     5
# 1479  Specifications  22.54 kmpl  1396 CC   88.73bhp   219.7Nm     5
# 1480  Specifications   18.9 kmpl  1197 CC      82bhp     114Nm     5
#
#      Wheel Size
# 0           NaN
# 1            16
# 2            14
# 3            14
# 4            16
# ...         ...
# ...

# %%
Bangalore_cars["car_links"]
# Out:
# 0       https://www.cardekho.com/used-car-details/used...
# 1       https://www.cardekho.com/buy-used-car-details/...
# 2       https://www.cardekho.com/used-car-details/used...
# 3       https://www.cardekho.com/buy-used-car-details/...
# 4       https://www.cardekho.com/used-car-details/used...
#                               ...
# 1476    https://www.cardekho.com/used-car-details/used...
# 1477    https://www.cardekho.com/used-car-details/used...
# 1478    https://www.cardekho.com/used-car-details/used...
# 1479    https://www.cardekho.com/used-car-details/used...
# 1480    https://www.cardekho.com/used-car-details/used...
# Name: car_links, Length: 1481, dtype: object

# %%
import pandas as pd

df_15=pd.DataFrame(Bangalore_cars["car_links"])

df_15
# Out:
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1476  https://www.cardekho.com/used-car-details/used...
# 1477  https://www.cardekho.com/used-car-details/used...
# 1478  https://www.cardekho.com/used-car-details/used...
# 1479  https://www.cardekho.com/used-car-details/used...
# 1480  https://www.cardekho.com/used-car-details/used...
#
# [1481 rows x 1 columns]

# %%
import pandas as pd

df_13_truncated = df_13.iloc[:1481]


overall_bangalore_df = pd.concat([df_11,df_12,df_13_truncated,df_14,df_15], axis=1)

overall_bangalore_df
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1476   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 1477   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 1478   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 1479   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 1480   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem               model  modelYear  ...  \
# 0      Maruti      Maruti Celerio       2015  ...
# ...

# %%
overall_bangalore_df["City"]="Bangalore"
overall_bangalore_df
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1476   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 1477   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 1478   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 1479   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 1480   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem               model  modelYear  ...  \
# 0      Maruti      Maruti Celerio       2015  ...
# ...

# %%
overall_bangalore_df.to_csv("overall_bangalore_df.csv",index=False)

# %%
                                DELHI CAR DETAILS

import pandas as pd
Delhi_cars= pd.read_csv("G:/delhi_cars - delhi_cars.csv.csv")

# %%
Delhi_cars
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1480  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1481  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1482  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1483  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1484  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
Delhi_cars["new_car_detail"]
# Out:
# 0       {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1       {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2       {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3       {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4       {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
#                               ...
# 1480    {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1481    {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1482    {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1483    {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1484    {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# Name: new_car_detail, Length: 1485, dtype: object

# %%
list_of_dicts21 = Delhi_cars["new_car_detail"].tolist()

# %%
import pandas as pd
import ast

data= list_of_dicts21

data_dict = [ast.literal_eval(item) for item in data]

df_21=pd.json_normalize(data_dict)

df_21
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1      0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2      0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4      0  Petrol        SUV  60,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1480   0  Petrol      Sedan  60,000    Automatic        1  1st Owner
# 1481   0  Petrol        SUV  20,000       Manual        1  1st Owner
# 1482   0  Petrol      Sedan  60,000       Manual        1  1st Owner
# 1483   0  Diesel        SUV  38,000       Manual        1  1st Owner
# 1484   0  Diesel        SUV   7,000    Automatic        0  0th Owner
#
#                 oem              model  modelYear  centralVariantId  \
# 0               Kia         Kia Seltos       2022              7121
# ...

# %%
Delhi_cars["new_car_overview"]
# Out:
# 0       {'heading': 'Car overview', 'top': [{'key': 'R...
# 1       {'heading': 'Car overview', 'top': [{'key': 'R...
# 2       {'heading': 'Car overview', 'top': [{'key': 'R...
# 3       {'heading': 'Car overview', 'top': [{'key': 'R...
# 4       {'heading': 'Car overview', 'top': [{'key': 'R...
#                               ...
# 1480    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1481    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1482    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1483    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1484    {'heading': 'Car overview', 'top': [{'key': 'I...
# Name: new_car_overview, Length: 1485, dtype: object

# %%
list_of_dicts22=Delhi_cars["new_car_overview"].tolist()

# %%
import pandas as pd
import ast  

data_dict2 = [ast.literal_eval(item) if isinstance(item, str) else item for item in list_of_dicts22]

flattened_data_list = []

for data_item in data_dict2:
    heading = data_item.get('heading', '')

    flattened_data = {'Heading': heading}

    if 'top' in data_item and isinstance(data_item['top'], list):
       for item in data_item['top']:
            key = item.get('key', '')
            value = item.get('value', '')
            if key and value:
                flattened_data[key] = value

  
    flattened_data_list.append(flattened_data)

df_22 = pd.DataFrame(flattened_data_list)

df_22
# Out:
#            Heading Registration Year     Insurance Validity Fuel Type  \
# 0     Car overview              2022  Third Party insurance    Diesel
# 1     Car overview          May 2016               Zero Dep    Petrol
# 2     Car overview          Dec 2020          Comprehensive    Petrol
# 3     Car overview          Jan 2019          Comprehensive    Petrol
# 4     Car overview              2017  Third Party insurance    Petrol
# ...            ...               ...                    ...       ...
# 1480  Car overview              2019  Third Party insurance    Petrol
# 1481  Car overview              2021  Third Party insurance    Petrol
# 1482  Car overview              2011  Third Party insurance    Petrol
# 1483  Car overview          Oct 2019  Third Party insurance    Diesel
# 1484  Car overview               NaN  Third Party insurance    Diesel
#
#         Seats  Kms Driven     Ownership Engine Displacement Transmission  \
# ...

# %%
Delhi_cars["new_car_feature"]
# Out:
# 0       {'heading': 'Features', 'top': [{'value': 'Pow...
# 1       {'heading': 'Features', 'top': [{'value': 'Pow...
# 2       {'heading': 'Features', 'top': [{'value': 'Pow...
# 3       {'heading': 'Features', 'top': [{'value': 'Pow...
# 4       {'heading': 'Features', 'top': [{'value': 'Pow...
#                               ...
# 1480    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1481    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1482    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1483    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1484    {'heading': 'Features', 'top': [{'value': 'Pow...
# Name: new_car_feature, Length: 1485, dtype: object

# %%
list_of_dicts23=Delhi_cars["new_car_feature"].tolist()

# %%
import pandas as pd
import ast

data = [ast.literal_eval(item) for item in list_of_dicts23]

top_features = []
category_features = {
    'Comfort & Convenience': [],
    'Interior': [],
    'Exterior': [],
    'Safety': [],
    'Entertainment & Communication': []
}

for entry in data:
    
    top_features += [item['value'] for item in entry['top']]

    for section in entry['data']:
        category_name = section['heading']
        if category_name in category_features: 
            for item in section['list']:
                category_features[category_name].append(item['value'])

max_len = max(len(top_features), *[len(category_features[cat]) for cat in category_features])

top_features += [''] * (max_len - len(top_features))
for cat in category_features:
    category_features[cat] += [''] * (max_len - len(category_features[cat]))

final_data = {
    'Top Features': top_features,
    'Comfort & Convenience': category_features['Comfort & Convenience'],
    'Interior': category_features['Interior'],
    'Exterior': category_features['Exterior'],
    'Safety': category_features['Safety'],
    'Entertainment & Communication': category_features['Entertainment & Communication']
}

df_23 = pd.DataFrame(final_data)

df_23
# Out:
#                  Top Features   Comfort & Convenience             Interior  \
# 0              Power Steering          Power Steering      Air Conditioner
# 1         Power Windows Front     Power Windows Front               Heater
# 2             Air Conditioner      Power Windows Rear  Adjustable Steering
# 3                      Heater     Air Quality Control     Digital Odometer
# 4      Adjustable Head Lights  Low Fuel Warning Light           Tachometer
# ...                       ...                     ...                  ...
# 36356
# 36357
# 36358
# 36359
# 36360
#
#                                          Exterior  \
# 0                          Adjustable Head Lights
# 1                                Fog Lights Front
# 2      Power Adjustable Exterior Rear View Mirror
# 3               Electric Folding Rear View Mirror
# 4                              Rain Sensing Wiper
# ...                                           ...
# 36356
# 36357
# 36358
# 36359
# 36360
#
# ...

# %%
Delhi_cars["new_car_specs"]
# Out:
# 0       {'heading': 'Specifications', 'top': [{'key': ...
# 1       {'heading': 'Specifications', 'top': [{'key': ...
# 2       {'heading': 'Specifications', 'top': [{'key': ...
# 3       {'heading': 'Specifications', 'top': [{'key': ...
# 4       {'heading': 'Specifications', 'top': [{'key': ...
#                               ...
# 1480    {'heading': 'Specifications', 'top': [{'key': ...
# 1481    {'heading': 'Specifications', 'top': [{'key': ...
# 1482    {'heading': 'Specifications', 'top': [{'key': ...
# 1483    {'heading': 'Specifications', 'top': [{'key': ...
# 1484    {'heading': 'Specifications', 'top': [{'key': ...
# Name: new_car_specs, Length: 1485, dtype: object

# %%
list_of_dicts24=Delhi_cars["new_car_specs"].tolist()

# %%
import pandas as pd
import ast  


data_dict4 = [ast.literal_eval(item) if isinstance(item, str) else item for item in list_of_dicts24]

flattened_data_list = []

for data_item in data_dict4:
    heading = data_item.get('heading', '')

   flattened_data = {'Heading': heading}

    if 'top' in data_item and isinstance(data_item['top'], list):
       for item in data_item['top']:
            key = item.get('key', '')
            value = item.get('value', '')
           if key and value:
                flattened_data[key] = value

   
    flattened_data_list.append(flattened_data)


df_24 = pd.DataFrame(flattened_data_list)

df_24
# Out:
#              Heading     Mileage   Engine  Max Power    Torque Wheel Size  \
# 0     Specifications     18 kmpl  1493 CC  113.43bhp     250Nm         17
# 1     Specifications  15.29 kmpl  1591 CC   121.3bhp     151Nm        NaN
# 2     Specifications  12.74 kmpl  1991 CC     197bhp     320nm         19
# 3     Specifications  22.38 kmpl  1197 CC   88.50bhp     113Nm        NaN
# 4     Specifications  15.29 kmpl  1591 CC   121.3bhp     151Nm        NaN
# ...              ...         ...      ...        ...       ...        ...
# 1480  Specifications     18 kmpl  1497 CC   117.6bhp     145Nm         15
# 1481  Specifications   18.4 kmpl  1197 CC   81.86bhp     115Nm        NaN
# 1482  Specifications  17.01 kmpl  1591 CC   121.3bhp   154.9Nm         16
# 1483  Specifications   20.5 kmpl  1582 CC   126.2bhp  259.87NM         17
# 1484  Specifications  12.04 kmpl  1996 CC  212.55bhp   478.5Nm         19
#
#      Seats
# 0        5
# 1        5
# 2        5
# 3        5
# 4        5
# ...

# %%
Delhi_cars["car_links"]
# Out:
# 0       https://www.cardekho.com/used-car-details/used...
# 1       https://www.cardekho.com/buy-used-car-details/...
# 2       https://www.cardekho.com/used-car-details/used...
# 3       https://www.cardekho.com/buy-used-car-details/...
# 4       https://www.cardekho.com/used-car-details/used...
#                               ...
# 1480    https://www.cardekho.com/used-car-details/used...
# 1481    https://www.cardekho.com/used-car-details/used...
# 1482    https://www.cardekho.com/used-car-details/used...
# 1483    https://www.cardekho.com/used-car-details/used...
# 1484    https://www.cardekho.com/used-car-details/used...
# Name: car_links, Length: 1485, dtype: object

# %%
import pandas as pd

df_25=pd.DataFrame(Delhi_cars["car_links"])

df_25
# Out:
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1480  https://www.cardekho.com/used-car-details/used...
# 1481  https://www.cardekho.com/used-car-details/used...
# 1482  https://www.cardekho.com/used-car-details/used...
# 1483  https://www.cardekho.com/used-car-details/used...
# 1484  https://www.cardekho.com/used-car-details/used...
#
# [1485 rows x 1 columns]

# %%
import pandas as pd

df_23_truncated = df_23.iloc[:1485]


overall_delhi_df = pd.concat([df_21,df_22,df_23_truncated,df_24,df_25], axis=1)

overall_delhi_df
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1      0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2      0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4      0  Petrol        SUV  60,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1480   0  Petrol      Sedan  60,000    Automatic        1  1st Owner
# 1481   0  Petrol        SUV  20,000       Manual        1  1st Owner
# 1482   0  Petrol      Sedan  60,000       Manual        1  1st Owner
# 1483   0  Diesel        SUV  38,000       Manual        1  1st Owner
# 1484   0  Diesel        SUV   7,000    Automatic        0  0th Owner
#
#                 oem              model  modelYear  ...  \
# 0               Kia         Kia Seltos       2022  ...
# ...

# %%
overall_delhi_df["City"]="Delhi"
overall_delhi_df
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1      0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2      0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4      0  Petrol        SUV  60,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1480   0  Petrol      Sedan  60,000    Automatic        1  1st Owner
# 1481   0  Petrol        SUV  20,000       Manual        1  1st Owner
# 1482   0  Petrol      Sedan  60,000       Manual        1  1st Owner
# 1483   0  Diesel        SUV  38,000       Manual        1  1st Owner
# 1484   0  Diesel        SUV   7,000    Automatic        0  0th Owner
#
#                 oem              model  modelYear  ...  \
# 0               Kia         Kia Seltos       2022  ...
# ...

# %%
overall_delhi_df.to_csv("overall_delhi_df.csv",index=False)

# %%
                           HYDERABAD CAR DETAILS

import pandas as pd
Hyderabad_cars= pd.read_csv("G:/hyderabad_cars - hyderabad_cars.csv.csv")
Hyderabad_cars
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1478  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1479  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
# 1480  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
# 1481  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1482  {'it': 0, 'ft': 'Diesel', 'bt': 'MUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
Hyderabad_cars["new_car_detail"]
# Out:
# 0       {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1       {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2       {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3       {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4       {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
#                               ...
# 1478    {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1479    {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
# 1480    {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
# 1481    {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1482    {'it': 0, 'ft': 'Diesel', 'bt': 'MUV', 'km': '...
# Name: new_car_detail, Length: 1483, dtype: object

# %%
list_of_dicts31 = Hyderabad_cars["new_car_detail"].tolist()

# %%
import pandas as pd
import ast

data= list_of_dicts31

data_dict = [ast.literal_eval(item) for item in data]

df_31=pd.json_normalize(data_dict)

df_31
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback    20,000    Automatic        1  1st Owner
# 1      0  Petrol  Hatchback    85,582       Manual        2  2nd Owner
# 2      0  Petrol        SUV    10,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    50,750       Manual        1  1st Owner
# 4      0  Petrol        SUV    10,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1478   0  Diesel        SUV    60,000       Manual        1  1st Owner
# 1479   0  Diesel      Sedan    50,000    Automatic        1  1st Owner
# 1480   0  Diesel      Sedan  1,20,000    Automatic        3  3rd Owner
# 1481   0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# 1482   0  Diesel        MUV  1,00,000       Manual        1  1st Owner
#
#              oem            model  modelYear  centralVariantId  \
# ...

# %%
Hyderabad_cars["new_car_overview"]
# Out:
# 0       {'heading': 'Car overview', 'top': [{'key': 'R...
# 1       {'heading': 'Car overview', 'top': [{'key': 'R...
# 2       {'heading': 'Car overview', 'top': [{'key': 'R...
# 3       {'heading': 'Car overview', 'top': [{'key': 'R...
# 4       {'heading': 'Car overview', 'top': [{'key': 'R...
#                               ...
# 1478    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1479    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1480    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1481    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1482    {'heading': 'Car overview', 'top': [{'key': 'R...
# Name: new_car_overview, Length: 1483, dtype: object

# %%
list_of_dicts32=Hyderabad_cars["new_car_overview"].tolist()

# %%
import pandas as pd
import ast 

data_dict2 = [ast.literal_eval(item) if isinstance(item, str) else item for item in list_of_dicts32]

flattened_data_list = []

for data_item in data_dict2:
    heading = data_item.get('heading', '')
    
    flattened_data = {'Heading': heading}

    if 'top' in data_item and isinstance(data_item['top'], list):
        for item in data_item['top']:
            key = item.get('key', '')
            value = item.get('value', '')
           
            if key and value:
                flattened_data[key] = value

    
    flattened_data_list.append(flattened_data)

df_32 = pd.DataFrame(flattened_data_list)

df_32
# Out:
#            Heading Registration Year     Insurance Validity Fuel Type  \
# 0     Car overview              2022  Third Party insurance    Petrol
# 1     Car overview          Oct 2014  Third Party insurance    Petrol
# 2     Car overview              2023  Third Party insurance    Petrol
# 3     Car overview          Mar 2017  Third Party insurance    Petrol
# 4     Car overview              2022  Third Party insurance    Petrol
# ...            ...               ...                    ...       ...
# 1478  Car overview              2013  Third Party insurance    Diesel
# 1479  Car overview              2014  Third Party insurance    Diesel
# 1480  Car overview              2018  Third Party insurance    Diesel
# 1481  Car overview              2019  Third Party insurance    Diesel
# 1482  Car overview              2015  Third Party insurance    Diesel
#
#         Seats    Kms Driven   RTO     Ownership Engine Displacement  \
# ...

# %%
Hyderabad_cars["new_car_feature"]
# Out:
# 0       {'heading': 'Features', 'top': [{'value': 'Pow...
# 1       {'heading': 'Features', 'top': [{'value': 'Pow...
# 2       {'heading': 'Features', 'top': [{'value': 'Pow...
# 3       {'heading': 'Features', 'top': [{'value': 'Pow...
# 4       {'heading': 'Features', 'top': [{'value': 'Pow...
#                               ...
# 1478    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1479    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1480    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1481    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1482    {'heading': 'Features', 'top': [{'value': 'Pow...
# Name: new_car_feature, Length: 1483, dtype: object

# %%
list_of_dicts33=Hyderabad_cars["new_car_feature"].tolist()

# %%
import pandas as pd
import ast

data = [ast.literal_eval(item) for item in list_of_dicts33]

top_features = []
category_features = {
    'Comfort & Convenience': [],
    'Interior': [],
    'Exterior': [],
    'Safety': [],
    'Entertainment & Communication': []
}


for entry in data:
    top_features += [item['value'] for item in entry['top']]

    for section in entry['data']:
        category_name = section['heading']
        if category_name in category_features:  
            for item in section['list']:
                category_features[category_name].append(item['value'])

max_len = max(len(top_features), *[len(category_features[cat]) for cat in category_features])

top_features += [''] * (max_len - len(top_features))
for cat in category_features:
    category_features[cat] += [''] * (max_len - len(category_features[cat]))

final_data = {
    'Top Features': top_features,
    'Comfort & Convenience': category_features['Comfort & Convenience'],
    'Interior': category_features['Interior'],
    'Exterior': category_features['Exterior'],
    'Safety': category_features['Safety'],
    'Entertainment & Communication': category_features['Entertainment & Communication']
}


df_33 = pd.DataFrame(final_data)

df_33
# Out:
#                  Top Features   Comfort & Convenience             Interior  \
# 0              Power Steering          Power Steering      Air Conditioner
# 1         Power Windows Front     Power Windows Front               Heater
# 2             Air Conditioner      Power Windows Rear  Adjustable Steering
# 3                      Heater     Remote Trunk Opener     Digital Odometer
# 4      Adjustable Head Lights  Low Fuel Warning Light           Tachometer
# ...                       ...                     ...                  ...
# 33351
# 33352
# 33353
# 33354
# 33355
#
#                                          Exterior  \
# 0                          Adjustable Head Lights
# 1                                Fog Lights Front
# 2                                 Fog Lights Rear
# 3      Power Adjustable Exterior Rear View Mirror
# 4               Electric Folding Rear View Mirror
# ...                                           ...
# 33351
# 33352
# 33353
# 33354
# 33355
#
# ...

# %%
Hyderabad_cars["new_car_specs"]
# Out:
# 0       {'heading': 'Specifications', 'top': [{'key': ...
# 1       {'heading': 'Specifications', 'top': [{'key': ...
# 2       {'heading': 'Specifications', 'top': [{'key': ...
# 3       {'heading': 'Specifications', 'top': [{'key': ...
# 4       {'heading': 'Specifications', 'top': [{'key': ...
#                               ...
# 1478    {'heading': 'Specifications', 'top': [{'key': ...
# 1479    {'heading': 'Specifications', 'top': [{'key': ...
# 1480    {'heading': 'Specifications', 'top': [{'key': ...
# 1481    {'heading': 'Specifications', 'top': [{'key': ...
# 1482    {'heading': 'Specifications', 'top': [{'key': ...
# Name: new_car_specs, Length: 1483, dtype: object

# %%
list_of_dicts34=Hyderabad_cars["new_car_specs"].tolist()

# %%
import pandas as pd
import ast

data_dict4 = [ast.literal_eval(item) if isinstance(item, str) else item for item in list_of_dicts34]

flattened_data_list = []

for data_item in data_dict4:
    heading = data_item.get('heading', '')

   flattened_data = {'Heading': heading}

   if 'top' in data_item and isinstance(data_item['top'], list):
        for item in data_item['top']:
            key = item.get('key', '')
            value = item.get('value', '')
            if key and value:
                flattened_data[key] = value

   flattened_data_list.append(flattened_data)


df_34 = pd.DataFrame(flattened_data_list)

df_34
# Out:
#              Heading     Mileage   Engine  Max Power   Torque Wheel Size Seats
# 0     Specifications  16.47 kmpl   999 CC  108.62bhp    175nm        R16     5
# 1     Specifications   21.1 kmpl   814 CC    55.2bhp   74.5Nm        NaN     5
# 2     Specifications         NaN  1197 CC   81.80bhp  113.8Nm        NaN     5
# 3     Specifications   21.4 kmpl  1197 CC    83.1bhp    115Nm         16     5
# 4     Specifications         NaN  1997 CC     150bhp    320Nm         18     4
# ...              ...         ...      ...        ...      ...        ...   ...
# 1478  Specifications   15.1 kmpl  2179 CC     140bhp    330Nm         17     7
# 1479  Specifications  14.74 kmpl  2993 CC   270.9bhp    600Nm         20     5
# 1480  Specifications  20.37 kmpl  1995 CC  187.74bhp    400Nm        R18     5
# 1481  Specifications   21.5 kmpl  1497 CC   108.5bhp    260Nm        NaN     5
# 1482  Specifications  12.99 kmpl  2494 CC   100.6bhp    200Nm         15     7
#
# [1483 rows x 7 columns]

# %%
Hyderabad_cars["car_links"]
# Out:
# 0       https://www.cardekho.com/used-car-details/used...
# 1       https://www.cardekho.com/buy-used-car-details/...
# 2       https://www.cardekho.com/used-car-details/used...
# 3       https://www.cardekho.com/buy-used-car-details/...
# 4       https://www.cardekho.com/used-car-details/used...
#                               ...
# 1478    https://www.cardekho.com/used-car-details/used...
# 1479    https://www.cardekho.com/used-car-details/used...
# 1480    https://www.cardekho.com/used-car-details/used...
# 1481    https://www.cardekho.com/used-car-details/used...
# 1482    https://www.cardekho.com/used-car-details/used...
# Name: car_links, Length: 1483, dtype: object

# %%
import pandas as pd

df_35=pd.DataFrame(Hyderabad_cars["car_links"])

df_35
# Out:
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1478  https://www.cardekho.com/used-car-details/used...
# 1479  https://www.cardekho.com/used-car-details/used...
# 1480  https://www.cardekho.com/used-car-details/used...
# 1481  https://www.cardekho.com/used-car-details/used...
# 1482  https://www.cardekho.com/used-car-details/used...
#
# [1483 rows x 1 columns]

# %%
import pandas as pd

df_33_truncated = df_33.iloc[:1483]


overall_hyderabad_df = pd.concat([df_31,df_32,df_33_truncated,df_34,df_35], axis=1)

overall_hyderabad_df
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback    20,000    Automatic        1  1st Owner
# 1      0  Petrol  Hatchback    85,582       Manual        2  2nd Owner
# 2      0  Petrol        SUV    10,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    50,750       Manual        1  1st Owner
# 4      0  Petrol        SUV    10,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1478   0  Diesel        SUV    60,000       Manual        1  1st Owner
# 1479   0  Diesel      Sedan    50,000    Automatic        1  1st Owner
# 1480   0  Diesel      Sedan  1,20,000    Automatic        3  3rd Owner
# 1481   0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# 1482   0  Diesel        MUV  1,00,000       Manual        1  1st Owner
#
#              oem            model  modelYear  ...                    Safety  \
# ...

# %%
overall_hyderabad_df["City"]="Hyderabad"

# %%
overall_hyderabad_df
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback    20,000    Automatic        1  1st Owner
# 1      0  Petrol  Hatchback    85,582       Manual        2  2nd Owner
# 2      0  Petrol        SUV    10,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    50,750       Manual        1  1st Owner
# 4      0  Petrol        SUV    10,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1478   0  Diesel        SUV    60,000       Manual        1  1st Owner
# 1479   0  Diesel      Sedan    50,000    Automatic        1  1st Owner
# 1480   0  Diesel      Sedan  1,20,000    Automatic        3  3rd Owner
# 1481   0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# 1482   0  Diesel        MUV  1,00,000       Manual        1  1st Owner
#
#              oem            model  modelYear  ...  \
# 0     Volkswagen  Volkswagen Polo       2022  ...
# ...

# %%
overall_hyderabad_df.to_csv("overall_hyderabad_df.csv",index=False)

# %%
                                 JAIPUR CAR DETAILS

import pandas as pd
Jaipur_cars= pd.read_csv("G:/jaipur_cars - jaipur_cars.csv.csv")
Jaipur_cars
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...                                                 ...
# 1115  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1116  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1117  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1118  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1119  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
list_of_dicts41=Jaipur_cars["new_car_detail"].tolist()

# %%
import pandas as pd
import ast

data= list_of_dicts41

data_dict = [ast.literal_eval(item) for item in data]

df_41=pd.json_normalize(data_dict)

df_41
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner
# 1      0  Petrol  Hatchback    66,951       Manual        1  1st Owner
# 2      0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner
# 3      0  Petrol  Hatchback    44,392       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    40,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1115   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1116   0  Petrol  Hatchback    70,000       Manual        1  1st Owner
# 1117   0  Petrol        SUV    20,000       Manual        1  1st Owner
# 1118   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1119   0  Petrol  Hatchback    80,000       Manual        1  1st Owner
#
#             oem              model  modelYear  centralVariantId  \
# ...

# %%
list_of_dicts42=Jaipur_cars["new_car_overview"].tolist()

# %%
import pandas as pd
import ast 

data_dict2 = [ast.literal_eval(item) if isinstance(item, str) else item for item in list_of_dicts42]

flattened_data_list = []

for data_item in data_dict2:
    heading = data_item.get('heading', '')

    flattened_data = {'Heading': heading}

   if 'top' in data_item and isinstance(data_item['top'], list):
       for item in data_item['top']:
           key = item.get('key', '')
           value = item.get('value', '')
            
            if key and value:
                flattened_data[key] = value

   
    flattened_data_list.append(flattened_data)


df_42 = pd.DataFrame(flattened_data_list)

df_42
# Out:
#            Heading Registration Year     Insurance Validity Fuel Type  \
# 0     Car overview              2015  Third Party insurance    Diesel
# 1     Car overview          Jan 2012            Third Party    Petrol
# 2     Car overview              2016  Third Party insurance    Petrol
# 3     Car overview          Apr 2017  Third Party insurance    Petrol
# 4     Car overview              2016  Third Party insurance    Petrol
# ...            ...               ...                    ...       ...
# 1115  Car overview              2011  Third Party insurance    Petrol
# 1116  Car overview              2007  Third Party insurance    Petrol
# 1117  Car overview              2022  Third Party insurance    Petrol
# 1118  Car overview              2009  Third Party insurance    Petrol
# 1119  Car overview              2018  Third Party insurance    Petrol
#
#         Seats    Kms Driven   RTO     Ownership Engine Displacement  \
# ...

# %%
list_of_dicts43=Jaipur_cars["new_car_feature"].tolist()

# %%
import pandas as pd
import ast

data = [ast.literal_eval(item) for item in list_of_dicts43]

top_features = []
category_features = {
    'Comfort & Convenience': [],
    'Interior': [],
    'Exterior': [],
    'Safety': [],
    'Entertainment & Communication': []
}

for entry in data:
    top_features += [item['value'] for item in entry['top']]

    for section in entry['data']:
        category_name = section['heading']
        if category_name in category_features:  
            for item in section['list']:
                category_features[category_name].append(item['value'])


max_len = max(len(top_features), *[len(category_features[cat]) for cat in category_features])

top_features += [''] * (max_len - len(top_features))
for cat in category_features:
    category_features[cat] += [''] * (max_len - len(category_features[cat]))

final_data = {
    'Top Features': top_features,
    'Comfort & Convenience': category_features['Comfort & Convenience'],
    'Interior': category_features['Interior'],
    'Exterior': category_features['Exterior'],
    'Safety': category_features['Safety'],
    'Entertainment & Communication': category_features['Entertainment & Communication']
}

df_43 = pd.DataFrame(final_data)

df_43
# Out:
#                  Top Features Comfort & Convenience             Interior  \
# 0              Power Steering        Power Steering      Air Conditioner
# 1         Power Windows Front   Power Windows Front               Heater
# 2             Air Conditioner    Power Windows Rear  Adjustable Steering
# 3                      Heater   Air Quality Control     Digital Odometer
# 4      Adjustable Head Lights   Remote Trunk Opener           Tachometer
# ...                       ...                   ...                  ...
# 23310
# 23311
# 23312
# 23313
# 23314
#
#                                          Exterior  \
# 0                          Adjustable Head Lights
# 1                                Fog Lights Front
# 2      Power Adjustable Exterior Rear View Mirror
# 3               Electric Folding Rear View Mirror
# 4                               Rear Window Wiper
# ...                                           ...
# 23310
# 23311
# 23312
# 23313
# 23314
#
# ...

# %%
list_of_dicts44=Jaipur_cars["new_car_specs"].tolist()

# %%
import pandas as pd
import ast 

data_dict4 = [ast.literal_eval(item) if isinstance(item, str) else item for item in list_of_dicts44]

flattened_data_list = []

for data_item in data_dict4:
   
    heading = data_item.get('heading', '')
    flattened_data = {'Heading': heading}
    
    if 'top' in data_item and isinstance(data_item['top'], list):
       for item in data_item['top']:
           
           key = item.get('key', '')
           value = item.get('value', '')
           if key and value:
                flattened_data[key] = value

   flattened_data_list.append(flattened_data)


df_44 = pd.DataFrame(flattened_data_list)
df_44
# Out:
#              Heading     Mileage   Engine Max Power    Torque Wheel Size Seats
# 0     Specifications  22.54 kmpl  1396 CC  88.73bhp   219.7Nm         16     5
# 1     Specifications  22.38 kmpl  1197 CC  88.50bhp     113Nm        NaN     5
# 2     Specifications   23.1 kmpl   998 CC  67.04bhp      90Nm        NaN     5
# 3     Specifications   18.9 kmpl  1197 CC  81.86bhp  113.75nm        NaN     5
# 4     Specifications  20.51 kmpl   998 CC     67bhp      90Nm        NaN     5
# ...              ...         ...      ...       ...       ...        ...   ...
# 1115  Specifications   18.6 kmpl  1199 CC   79.4bhp     108Nm         14     5
# 1116  Specifications   19.7 kmpl   796 CC   46.3bhp      62Nm         12     5
# 1117  Specifications  19.17 kmpl   999 CC  71.01bhp      96Nm         16     5
# 1118  Specifications   19.7 kmpl   796 CC   46.3bhp      62Nm         12     5
# 1119  Specifications   21.4 kmpl  1197 CC   83.1bhp     115Nm        NaN     5
#
# [1120 rows x 7 columns]

# %%
import pandas as pd

df_45=pd.DataFrame(Jaipur_cars["car_links"])

df_45
# Out:
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1115  https://www.cardekho.com/used-car-details/used...
# 1116  https://www.cardekho.com/used-car-details/used...
# 1117  https://www.cardekho.com/used-car-details/used...
# 1118  https://www.cardekho.com/used-car-details/used...
# 1119  https://www.cardekho.com/used-car-details/used...
#
# [1120 rows x 1 columns]

# %%
import pandas as pd

df_43_truncated = df_43.iloc[:1120]


overall_jaipur_df = pd.concat([df_41,df_42,df_43_truncated,df_44,df_45], axis=1)

overall_jaipur_df
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner
# 1      0  Petrol  Hatchback    66,951       Manual        1  1st Owner
# 2      0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner
# 3      0  Petrol  Hatchback    44,392       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    40,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1115   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1116   0  Petrol  Hatchback    70,000       Manual        1  1st Owner
# 1117   0  Petrol        SUV    20,000       Manual        1  1st Owner
# 1118   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1119   0  Petrol  Hatchback    80,000       Manual        1  1st Owner
#
#             oem              model  modelYear  ...                    Safety  \
# ...

# %%
overall_jaipur_df["City"]="Jaipur"

# %%
overall_jaipur_df
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner
# 1      0  Petrol  Hatchback    66,951       Manual        1  1st Owner
# 2      0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner
# 3      0  Petrol  Hatchback    44,392       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    40,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1115   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1116   0  Petrol  Hatchback    70,000       Manual        1  1st Owner
# 1117   0  Petrol        SUV    20,000       Manual        1  1st Owner
# 1118   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1119   0  Petrol  Hatchback    80,000       Manual        1  1st Owner
#
#             oem              model  modelYear  ...  \
# 0       Hyundai        Hyundai i20       2015  ...
# ...

# %%
overall_jaipur_df.to_csv("overall_jaipur_df.csv",index=False)

# %%
                                   KOLKATA CAR DETAILS

import pandas as pd
Kolkata_cars= pd.read_csv("G:/kolkata_cars - kolkata_cars.csv.csv")
Kolkata_cars
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1376  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1377  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1378  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1379  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1380  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
list_of_dicts51=Kolkata_cars["new_car_detail"].tolist()

# %%
import pandas as pd
import ast

data= list_of_dicts51

data_dict = [ast.literal_eval(item) for item in data]

df_51=pd.json_normalize(data_dict)

df_51
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol      Sedan    70,000    Automatic        3  3rd Owner
# 1      0  Petrol  Hatchback    23,981       Manual        1  1st Owner
# 2      0  Petrol        SUV     7,100    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback    71,574       Manual        2  2nd Owner
# 4      0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1376   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 1377   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1378   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 1379   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1380   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  centralVariantId  \
# ...

# %%
list_of_dicts52=Kolkata_cars["new_car_overview"].tolist()

# %%
import pandas as pd
import ast

data_dict2 = [ast.literal_eval(item) if isinstance(item, str) else item for item in list_of_dicts52]

flattened_data_list = []

for data_item in data_dict2:
    heading = data_item.get('heading', '')
    
    flattened_data = {'Heading': heading}

    
    if 'top' in data_item and isinstance(data_item['top'], list):
       
        for item in data_item['top']:
            key = item.get('key', '')
            value = item.get('value', '')
           
            if key and value:
                flattened_data[key] = value

   
    flattened_data_list.append(flattened_data)


df_52 = pd.DataFrame(flattened_data_list)
df_52
# Out:
#            Heading Registration Year     Insurance Validity Fuel Type  \
# 0     Car overview              2014  Third Party insurance    Petrol
# 1     Car overview          Jul 2017          Comprehensive    Petrol
# 2     Car overview          Nov 2021          Comprehensive    Petrol
# 3     Car overview          Feb 2012            Third Party    Petrol
# 4     Car overview              2014  Third Party insurance    Diesel
# ...            ...               ...                    ...       ...
# 1376  Car overview              2022  Third Party insurance    Petrol
# 1377  Car overview              2014  Third Party insurance    Petrol
# 1378  Car overview              2011  Third Party insurance    Petrol
# 1379  Car overview              2012  Third Party insurance    Petrol
# 1380  Car overview              2017  Third Party insurance    Diesel
#
#         Seats    Kms Driven   RTO     Ownership Engine Displacement  \
# ...

# %%
list_of_dicts53=Kolkata_cars["new_car_feature"].tolist()

# %%
import pandas as pd
import ast


data = [ast.literal_eval(item) for item in list_of_dicts53]

top_features = []
category_features = {
    'Comfort & Convenience': [],
    'Interior': [],
    'Exterior': [],
    'Safety': [],
    'Entertainment & Communication': []
}

for entry in data:
    top_features += [item['value'] for item in entry['top']]
    
    for section in entry['data']:
        category_name = section['heading']
        if category_name in category_features: 
            for item in section['list']:
                category_features[category_name].append(item['value'])


max_len = max(len(top_features), *[len(category_features[cat]) for cat in category_features])


top_features += [''] * (max_len - len(top_features))
for cat in category_features:
    category_features[cat] += [''] * (max_len - len(category_features[cat]))


final_data = {
    'Top Features': top_features,
    'Comfort & Convenience': category_features['Comfort & Convenience'],
    'Interior': category_features['Interior'],
    'Exterior': category_features['Exterior'],
    'Safety': category_features['Safety'],
    'Entertainment & Communication': category_features['Entertainment & Communication']
}


df_53 = pd.DataFrame(final_data)
df_53
# Out:
#                  Top Features Comfort & Convenience             Interior  \
# 0              Power Steering        Power Steering      Air Conditioner
# 1         Power Windows Front   Power Windows Front               Heater
# 2             Air Conditioner    Power Windows Rear  Adjustable Steering
# 3                      Heater   Air Quality Control     Digital Odometer
# 4      Adjustable Head Lights   Remote Trunk Opener           Tachometer
# ...                       ...                   ...                  ...
# 30730
# 30731
# 30732
# 30733
# 30734
#
#                                          Exterior  \
# 0                          Adjustable Head Lights
# 1                                Fog Lights Front
# 2                                 Fog Lights Rear
# 3      Power Adjustable Exterior Rear View Mirror
# 4               Electric Folding Rear View Mirror
# ...                                           ...
# 30730
# 30731
# 30732
# 30733
# 30734
#
# ...

# %%
list_of_dicts54=Kolkata_cars["new_car_specs"].tolist()

# %%
import pandas as pd
import ast  

data_dict4 = [ast.literal_eval(item) if isinstance(item, str) else item for item in list_of_dicts54]

flattened_data_list = []

for data_item in data_dict4:
    heading = data_item.get('heading', '')
    
    flattened_data = {'Heading': heading}
    
    if 'top' in data_item and isinstance(data_item['top'], list):
        
        for item in data_item['top']:
            
            key = item.get('key', '')
            value = item.get('value', '')
            
            if key and value:
                flattened_data[key] = value

   
    flattened_data_list.append(flattened_data)


df_54 = pd.DataFrame(flattened_data_list)
df_54
# Out:
#              Heading     Mileage   Engine          Max Power  \
# 0     Specifications  19.16 kmpl  2494 CC           158.2bhp
# 1     Specifications   22.7 kmpl   799 CC           53.64bhp
# 2     Specifications  19.03 kmpl   999 CC           71.01bhp
# 3     Specifications     17 kmpl  1197 CC  80 PS at 5200 rpm
# 4     Specifications  15.73 kmpl  1968 CC          174.33bhp
# ...              ...         ...      ...                ...
# 1376  Specifications  25.24 kmpl   998 CC           65.71bhp
# 1377  Specifications  22.74 kmpl   796 CC            47.3bhp
# 1378  Specifications  11.74 kmpl  1796 CC             186bhp
# 1379  Specifications   18.5 kmpl  1197 CC           85.80bhp
# 1380  Specifications  19.72 kmpl  1461 CC          108.45bhp
#
#                      Torque Wheel Size Seats
# 0                     213Nm         17     5
# 1                      72Nm        NaN     5
# 2                      96Nm        NaN     5
# 3     11.4 kgm at 4,000 rpm         14     5
# ...

# %%
import pandas as pd

df_55=pd.DataFrame(Kolkata_cars["car_links"])

df_55
# Out:
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1376  https://www.cardekho.com/used-car-details/used...
# 1377  https://www.cardekho.com/used-car-details/used...
# 1378  https://www.cardekho.com/used-car-details/used...
# 1379  https://www.cardekho.com/used-car-details/used...
# 1380  https://www.cardekho.com/used-car-details/used...
#
# [1381 rows x 1 columns]

# %%
import pandas as pd

df_53_truncated = df_53.iloc[:1381]


overall_kolkata_df = pd.concat([df_51,df_52,df_53_truncated,df_54,df_55], axis=1)

overall_kolkata_df
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol      Sedan    70,000    Automatic        3  3rd Owner
# 1      0  Petrol  Hatchback    23,981       Manual        1  1st Owner
# 2      0  Petrol        SUV     7,100    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback    71,574       Manual        2  2nd Owner
# 4      0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1376   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 1377   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1378   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 1379   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1380   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...  \
# ...

# %%
overall_kolkata_df["City"]="Kolkata"

# %%
overall_kolkata_df
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol      Sedan    70,000    Automatic        3  3rd Owner
# 1      0  Petrol  Hatchback    23,981       Manual        1  1st Owner
# 2      0  Petrol        SUV     7,100    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback    71,574       Manual        2  2nd Owner
# 4      0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1376   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 1377   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1378   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 1379   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1380   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...  \
# ...

# %%
overall_kolkata_df.to_csv("overall_kolkata_df.csv",index=False)

# %%
import pandas as pd


overall_totalcities_df=pd.concat([overall_chennai_df1,overall_bangalore_df1,overall_delhi_df1,overall_hyderabad_df1,overall_jaipur_df1,overall_kolkata_df1], axis=0,ignore_index=True)

overall_totalcities_df
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV    20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans    20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV    30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    50,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 8364   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 8365   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 8366   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 8367   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 8368   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...  \
# ...

# %%
overall_totalcities_df.to_csv("overall_totalcities_df.csv",index=False)
